# %%
import pandas as pd
import numpy as np
import warnings

import pylab 
import seaborn as sns
sns.set(style="ticks", color_codes=True, font_scale=1.5)
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from matplotlib.colors import ListedColormap
# %matplotlib inline
import mpl_toolkits
from mpl_toolkits.mplot3d import Axes3D
from graphviz import Source
from IPython.display import Image

from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold, cross_val_predict, train_test_split
from sklearn.metrics import roc_auc_score, roc_curve, auc, accuracy_score

from sklearn.linear_model import LogisticRegression
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.ensemble.gradient_boosting import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from mlxtend.classifier import StackingClassifier
# Out:
# C:\Users\paige\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.ensemble.gradient_boosting module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
redwinequality = "Resources/winequality-red.csv"

# %%
df_redwinequality = pd.read_csv(redwinequality, encoding="ISO-8859-1")

# %%
df_redwinequality.head(100)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# ..            ...               ...          ...             ...        ...
# 95            4.7             0.600         0.17             2.3      0.058
# 96            6.8             0.775         0.00             3.0      0.102
# 97            7.0             0.500         0.25             2.0      0.070
# 98            7.6             0.900         0.06             2.5      0.079
# 99            8.1             0.545         0.18             1.9      0.080
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
# ..                  ...                   ...      ...   ...        ...
# 95                 17.0                 106.0   0.9932  3.85       0.60
# 96                  8.0                  23.0   0.9965  3.45       0.56
# 97                  3.0                  22.0   0.9963  3.25       0.63
# 98                  5.0                  10.0   0.9967  3.39       0.56
# 99                 13.0                  35.0   0.9972  3.30       0.59
#
#     alcohol  quality
# 0       9.4        5
# 1       9.8        5
# 2       9.8        5
# 3       9.8        6
# 4       9.4        5
# ..      ...      ...
# 95     12.9        6
# 96     10.7        5
# 97      9.2        5
# 98      9.8        5
# 99      9.0        6
#
# [100 rows x 12 columns]

# %%
df_redwinequality.count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
df_redwinequality = df_redwinequality.dropna(how='any')

# %%
df_redwinequality.count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
df_redwinequality.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
df_redwinequality_new = df_redwinequality[['volatile acidity','sulphates','citric acid','alcohol','residual sugar','fixed acidity','chlorides','free sulfur dioxide','total sulfur dioxide','pH','quality']].copy()

# %%
df_redwinequality_new = df_redwinequality_new.rename(columns = {'volatile acidity': 'volatile_acidity', 'citric acid': 'citric_acid','residual sugar':'residual_sugar', 'fixed acidity':'fixed_acidity','free sulfur dioxide':'free_sulfur_dioxide','total sulfur dioxide':'total_sulfur_dioxide'}, inplace = False)
df_redwinequality_new.head()
# Out:
#    volatile_acidity  sulphates  citric_acid  alcohol  residual_sugar  \
# 0              0.70       0.56         0.00      9.4             1.9
# 1              0.88       0.68         0.00      9.8             2.6
# 2              0.76       0.65         0.04      9.8             2.3
# 3              0.28       0.58         0.56      9.8             1.9
# 4              0.70       0.56         0.00      9.4             1.9
#
#    fixed_acidity  chlorides  free_sulfur_dioxide  total_sulfur_dioxide    pH  \
# 0            7.4      0.076                 11.0                  34.0  3.51
# 1            7.8      0.098                 25.0                  67.0  3.20
# 2            7.8      0.092                 15.0                  54.0  3.26
# 3           11.2      0.075                 17.0                  60.0  3.16
# 4            7.4      0.076                 11.0                  34.0  3.51
#
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %%
df_redwinequality_new['quality_label'] = df_redwinequality_new.quality.apply(lambda q: '1' if q <= 5 else '2' if q < 7 else '3')
df_redwinequality_new.head()
# Out:
#    volatile_acidity  sulphates  citric_acid  alcohol  residual_sugar  \
# 0              0.70       0.56         0.00      9.4             1.9
# 1              0.88       0.68         0.00      9.8             2.6
# 2              0.76       0.65         0.04      9.8             2.3
# 3              0.28       0.58         0.56      9.8             1.9
# 4              0.70       0.56         0.00      9.4             1.9
#
#    fixed_acidity  chlorides  free_sulfur_dioxide  total_sulfur_dioxide    pH  \
# 0            7.4      0.076                 11.0                  34.0  3.51
# 1            7.8      0.098                 25.0                  67.0  3.20
# 2            7.8      0.092                 15.0                  54.0  3.26
# 3           11.2      0.075                 17.0                  60.0  3.16
# 4            7.4      0.076                 11.0                  34.0  3.51
#
#    quality quality_label
# 0        5             1
# 1        5             1
# 2        5             1
# 3        6             2
# 4        5             1

# %%
ls = round(df_redwinequality_new[df_redwinequality_new['quality_label'] == '1'].describe(),2)
ms = round(df_redwinequality_new[df_redwinequality_new['quality_label'] == '2'].describe(),2)
hs = round(df_redwinequality_new[df_redwinequality_new['quality_label'] == '3'].describe(),2)
pd.concat([ls, ms, hs], axis=0, keys=['Low Quality Wine', 'Medium Quality Wine', 'High Quality Wine']).T
# Out:
#                      Low Quality Wine                                    \
#                                 count   mean    std   min    25%    50%
# volatile_acidity                744.0   0.59   0.18  0.18   0.46   0.59
# sulphates                       744.0   0.62   0.18  0.33   0.52   0.58
# citric_acid                     744.0   0.24   0.18  0.00   0.08   0.22
# alcohol                         744.0   9.93   0.76  8.40   9.40   9.70
# residual_sugar                  744.0   2.54   1.39  1.20   1.90   2.20
# fixed_acidity                   744.0   8.14   1.57  4.60   7.10   7.80
# chlorides                       744.0   0.09   0.06  0.04   0.07   0.08
# free_sulfur_dioxide             744.0  16.57  10.89  3.00   8.00  14.00
# total_sulfur_dioxide            744.0  54.65  36.72  6.00  23.75  45.00
# pH                              744.0   3.31   0.15  2.74   3.20   3.31
# quality                         744.0   4.90   0.34  3.00   5.00   5.00
#
#                                     Medium Quality Wine         ...         \
#                         75%     max               count   mean  ...    75%
# volatile_acidity       0.68    1.58               638.0   0.50  ...   0.60
# sulphates              0.65    2.00               638.0   0.68  ...   0.75
# citric_acid            0.36    1.00               638.0   0.27  ...   0.43
# alcohol               10.30   14.90               638.0  10.63  ...  11.30
# residual_sugar         2.60   15.50               638.0   2.48  ...   2.50
# fixed_acidity          8.90   15.90               638.0   8.35  ...   9.40
# chlorides              0.09    0.61               638.0   0.08  ...   0.09
# free_sulfur_dioxide   23.00   68.00               638.0  15.71  ...  21.00
# total_sulfur_dioxide  78.00  155.00               638.0  40.87  ...  54.00
# pH                     3.40    3.90               638.0   3.32  ...   3.41
# quality                5.00    5.00               638.0   6.00  ...   6.00
#
#                              High Quality Wine                             \
#                          max             count   mean    std   min    25%
# volatile_acidity        1.04             217.0   0.41   0.14  0.12   0.30
# sulphates               1.95             217.0   0.74   0.13  0.39   0.65
# citric_acid             0.78             217.0   0.38   0.19  0.00   0.30
# alcohol                14.00             217.0  11.52   1.00  9.20  10.80
# residual_sugar         15.40             217.0   2.71   1.36  1.20   2.00
# fixed_acidity          14.30             217.0   8.85   2.00  4.90   7.40
# chlorides               0.42             217.0   0.08   0.03  0.01   0.06
# free_sulfur_dioxide    72.00             217.0  13.98  10.23  3.00   6.00
# total_sulfur_dioxide  165.00             217.0  34.89  32.57  7.00  17.00
# pH                      4.01             217.0   3.29   0.15  2.88   3.20
# quality                 6.00             217.0   7.08   0.28  7.00   7.00
#
#
#                         50%    75%     max
# volatile_acidity       0.37   0.49    0.92
# sulphates              0.74   0.82    1.36
# citric_acid            0.40   0.49    0.76
# alcohol               11.60  12.20   14.00
# residual_sugar         2.30   2.70    8.90
# fixed_acidity          8.70  10.10   15.60
# chlorides              0.07   0.08    0.36
# free_sulfur_dioxide   11.00  18.00   54.00
# total_sulfur_dioxide  27.00  43.00  289.00
# pH                     3.27   3.38    3.78
# quality                7.00   7.00    8.00
#
# [11 rows x 24 columns]

# %%
corr = df_redwinequality_new.corr()
top_corr_cols = corr.quality.sort_values(ascending=False).keys() 
top_corr = corr.loc[top_corr_cols, top_corr_cols]
dropSelf = np.zeros_like(top_corr)
dropSelf[np.triu_indices_from(dropSelf)] = True
plt.figure(figsize=(18, 10))
sns.heatmap(top_corr, cmap=sns.diverging_palette(220, 10, as_cmap=True), annot=True, fmt=".2f", mask=dropSelf)
sns.set(font_scale=1.5)

sns.set(font_scale=1.0)
cols = df_redwinequality_new.columns
cols = cols.drop('quality')
g = sns.pairplot(data = df_redwinequality_new.loc[:, cols], hue='quality_label')
fig = g.fig 
fig.subplots_adjust(top=0.93, wspace=0.3)
t = fig.suptitle('Wine Attributes Pairwise Plots by Quality', fontsize=24)

plt.show()

del corr, dropSelf, top_corr, g, fig, t

# %%
numeric_features = list(wines.dtypes[(wines.dtypes != "str") & (wines.dtypes !='object')].index)
numeric_features.remove('color')

skewed_features = wines[numeric_features].apply(lambda x : skew (x.dropna())).sort_values(ascending=False)

#compute skewness
skewness = pd.DataFrame({'Skew' :skewed_features})   

# Get only higest skewed features
skewness = skewness[abs(skewness) > 0.7]
skewness = skewness.dropna()
print ("There are {} higest skewed numerical features to box cox transform".format(skewness.shape[0]))

l_opt = {}

for feat in skewness.index:
    wines[feat], l_opt[feat] = boxcox((wines[feat]+1))

skewed_features2 = wines[skewness.index].apply(lambda x : skew (x.dropna())).sort_values(ascending=False)

#compute skewness
skewness2 = pd.DataFrame({'New Skew' :skewed_features2})   
display(pd.concat([skewness, skewness2], axis=1).sort_values(by=['Skew'], ascending=False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-f0662172147a> in <module>
# ----> 1 numeric_features = list(wines.dtypes[(wines.dtypes != "str") & (wines.dtypes !='object')].index)
#       2 numeric_features.remove('color')
#       3
#       4 skewed_features = wines[numeric_features].apply(lambda x : skew (x.dropna())).sort_values(ascending=False)
#       5
#
# NameError: name 'wines' is not defined

# %%
skewness2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-df1297203a9b> in <module>
# ----> 1 skewness2.head()
#
# NameError: name 'skewness2' is not defined

# %%
from scipy import stats
r,p = stats.pearsonr(df_redwinequality_new.quality, df_redwinequality_new.sulphates)
#print(round(p,25))
print('The p-value for sulphates and quality is',(round(p,25)), 'which is less than 0.05; therefore the relationship between the two variables is statistically significant')
# Out:
# The p-value for sulphates and quality is 1.8e-24 which is less than 0.05; therefore the relationship between the two variables is statistically significant

# %%
r,p = stats.pearsonr(df_redwinequality_new.quality, df_redwinequality_new.volatile_acidity)
#print(p)
print('The p-value for volatile_acidity and quality is',(round(p,61)), 'which is less than 0.05; therefore the relationship between the two variables is statistically significant')
# Out:
# The p-value for volatile_acidity and quality is 2.05e-59 which is less than 0.05; therefore the relationship between the two variables is statistically significant

# %%
r,p = stats.pearsonr(df_redwinequality_new.quality, df_redwinequality_new.citric_acid)
#print(p)
print('The p-value for citric_acid and quality is',(round(p,22)), 'which is less than 0.05; therefore the relationship between the two variables is statistically significant')
# Out:
# The p-value for citric_acid and quality is 4.99e-20 which is less than 0.05; therefore the relationship between the two variables is statistically significant

# %%
r,p = stats.pearsonr(df_redwinequality_new.quality, df_redwinequality_new.alcohol)
print(p)
print('The p-value for alcohol and quality is',(round(p,93)), 'which is less than 0.05; therefore the relationship between the two variables is statistically significant')
# Out:
# 2.831476979241185e-91
# The p-value for alcohol and quality is 2.8299999999999984e-91 which is less than 0.05; therefore the relationship between the two variables is statistically significant

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
 X= df_redwinequality_new[['volatile_acidity', 'sulphates', 'citric_acid', 'alcohol','residual_sugar','fixed_acidity','chlorides','free_sulfur_dioxide','pH']]

# %%
y=df_redwinequality_new[['quality_label']]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# Fitting our model with all of our features in X
model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")
print('The R2 Score for the model is',(round(score,6)),', therefore, the model explains > 36% of the variability of the response data around its mean.')
# Out:
# R2 Score: 0.36491500456040016
# The R2 Score for the model is 0.364915 , therefore, the model explains > 36% of the variability of the response data around its mean.

# %%
fig = plt.figure(figsize = (18, 4))
title = fig.suptitle("Red Wine Quality", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax1 = fig.add_subplot(1,4, 1)
ax1.set_title("Red Wine")
ax1.set_xlabel("Quality")
ax1.set_ylabel("Frequency") 
rw_q = df_redwinequality_new.quality.value_counts()
rw_q = (list(rw_q.index), list(rw_q.values))
ax1.set_ylim([0,1000])
ax1.tick_params(axis='both', which='major', labelsize=8.5)
bar1 = ax1.bar(rw_q[0], rw_q[1], color='red', edgecolor='black', linewidth=1)

ax3 = fig.add_subplot(1,4, 3)
ax3.set_title("Red Wine")
ax3.set_xlabel("Quality Label")
ax3.set_ylabel("Frequency") 
rw_q = df_redwinequality_new.quality_label.value_counts()
rw_q = (list(rw_q.index), list(rw_q.values))
ax3.set_ylim([0, 1000])
bar3 = ax3.bar(list(range(len(rw_q[0]))), rw_q[1], color='red', edgecolor='black', linewidth=1, tick_label =rw_q[0])
